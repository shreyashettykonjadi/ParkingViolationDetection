# %%
import pandas as pd
import folium

clean_df = pd.read_csv(
    "../data/clean_parking_data.csv"
)

# %%
stations = sorted(
    clean_df["police_station"]
    .dropna()
    .unique()
)

len(stations)
# Out:
# 54

# %%
station = clean_df["police_station"].unique()[0]
hour = clean_df["hour"].unique()[0]


station_df = clean_df[
    clean_df["police_station"] == station
]

station_df.shape
# Out:
# (1563, 26)

# %%
hour_df = station_df[
    station_df["hour"] == hour
]

hour_df.shape
# Out:
# (44, 26)

# %%
sample_df = hour_df.head(500)

# %%
m = folium.Map(
    location=[12.9716,77.5946],
    zoom_start=11
)

# %%
for _, row in sample_df.iterrows():

    popup_text = f"""
                <b>Vehicle:</b> {row['vehicle_type']}<br>
                <b>Violation:</b> {row['primary_violation']}<br>
                <b>Station:</b> {row['police_station']}<br>
                <b>Hour:</b> {row['hour']}<br>
                <b>Junction:</b> {row['junction_name']}
                """

    folium.CircleMarker(
        location=[
            row["latitude"],
            row["longitude"]
        ],
        radius=3,
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7,
        popup=popup_text
    ).add_to(m)

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b89437d8f68482c924649282243f40fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b89437d8f68482c924649282243f40fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b89437d8f68482c924649282243f40fa = L.map(
#                 &quot;map_b89437d8f68482c924649282243f40fa&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a13481818efe3582a5565dd010a81d0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a13481818efe3582a5565dd010a81d0e.addTo(map_b89437d8f68482c924649282243f40fa);
#
#
#             var circle_marker_4d4203d59cc19a0c4675e2005fc36132 = L.circleMarker(
#                 [12.9255567, 77.618665],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b89437d8f68482c924649282243f40fa);
#
#
#         var popup_f541e9e60a2d4297a6aeb8a48dba7a93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73179165c5d2e8f62bcb9e537145d519 = $(`&lt;div id=&quot;html_73179165c5d2e8f62bcb9e537145d519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;Vehicle:&lt;/b&gt; CAR&lt;br&gt;                 &lt;b&gt;Violation:&lt;/b&gt; WRONG PARKING&lt;br&gt;                 &lt;b&gt;Station:&lt;/b&gt; Madiwala&lt;br&gt;                 &lt;b&gt;Hour:&lt;/b&gt; 0&lt;br&gt;                 &lt;b&gt;Junction:&lt;/b&gt; No Junction                 &lt;/div&gt;`)[0];
#                 popup_f541e9e60a2d4297a6aeb8a48dba7a93.setContent(html_73179165c5d2e8f62bcb9e537145d519);
#
#
#
#         circle_marker_4d4203d59cc19a0c4675e2005fc36132.bindPopup(popup_f541e9e60a2d4297a6aeb8a48dba7a93)
#         ;
#
#
#
#
#             var circle_marker_ab2f705e1e54f15b9c756310d3cc833c = L.circleMarker(
#                 [12.9254492, 77.6185035],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b89437d8f68482c924649282243f40fa);
#
#
#         var popup_00b230e53df505dbf6bb2bec7f0e4a71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ed6c7d7c62119b231d6ea4316141e52 = $(`&lt;div id=&quot;html_8ed6c7d7c62119b231d6ea4316141e52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;                 &lt;b&gt;Vehicle:&lt;/b&gt; CAR&lt;br&gt;                 &lt;b&gt;Violation:&lt;/b&gt; WRONG PARKING&lt;br&gt;                 &lt;b&gt;Station:&lt;/b&gt; Madiwala&lt;br&gt;                 &lt;b&gt;Hour:&lt;/b&gt; 0&lt;br&gt;                 &lt;b&gt;Junction:&lt;/b&gt; No Junction                 &lt;/div&gt;`)[0];
#                 popup_00b230e53df505dbf6bb2bec7f0e4a71.setContent(html_8ed6c7d7c62119b231d6ea4316141e52);
#
#
#
#         circle_marker_ab2f705e1e54f15b9c756310d3cc833c.bindPopup(popup_00b230e53df505dbf6bb2bec7f0e4a71)
#         ;
#
#
#
#
#             var circle_marker_24f0b9a3015dc26e9540807500e4159e = L.circleMarker(
#                 [12.906915, 77.628875],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b89437d8f68482c924649282243f40fa);
#
#
#         var popup_c093a923742bdd97871558d0c5fbad42 = L.popup({
#   &quot;m
