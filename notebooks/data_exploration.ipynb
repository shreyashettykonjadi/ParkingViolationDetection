# %%
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv("../data/parking_data.csv")
df["created_datetime"] = pd.to_datetime(
    df["created_datetime"],
    format="mixed",
    utc=True
)

print(df["created_datetime"].min())
print(df["created_datetime"].max())
# Out:
# 2023-11-09 19:11:46+00:00
# 2024-04-08 17:30:46+00:00

# %%
df["latitude"].describe()
# Out:
# count    298450.000000
# mean         12.980802
# std           0.049732
# min          12.802667
# 25%          12.963331
# 50%          12.977284
# 75%          12.997467
# max          13.293684
# Name: latitude, dtype: float64

# %%
df["longitude"].describe()
# Out:
# count    298450.000000
# mean         77.600512
# std           0.050518
# min          77.442553
# 25%          77.571198
# 50%          77.584114
# 75%          77.621529
# max          77.771735
# Name: longitude, dtype: float64

# %%
df["vehicle_type"].describe()
# Out:
# count      298450
# unique         22
# top       SCOOTER
# freq        94856
# Name: vehicle_type, dtype: object

# %%
df["police_station"].describe()
# Out:
# count       298445
# unique          54
# top       Upparpet
# freq         34468
# Name: police_station, dtype: object

# %%
df["police_station"].value_counts()
# Out:
# police_station
# Upparpet                  34468
# Shivajinagar              28044
# Malleshwaram              22200
# HAL Old Airport           20819
# City Market               17646
# Vijayanagara              14652
# Rajajinagar               10998
# Kodigehalli               10916
# Magadi Road                8558
# Jeevanbheemanagar          6736
# K.R. Pura                  6546
# Halasuru Gate              6294
# Mahadevapura               6187
# Chikkajala                 5834
# HSR Layout                 5018
# Bellandur                  4964
# High ground                4951
# Byatarayanapura            4555
# Electronic City            4333
# Pulikeshinagar(F.Town)     4136
# Halasur                    4011
# Jayanagara                 3813
# Chamarajpet                3795
# Banaswadi                  3759
# Basavanagudi               3604
# Ashok Nagar                3524
# Adugodi                    3332
# Cubbon Park                3255
# Hebbala                    3209
# Wilson Garden              3108
# Sheshadripuram             3090
# Mico Layout                2588
# Yeshwanthpura              2587
# Yelahanka                  2440
# Hulimavu                   2395
# Whitefield                 2303
# R.T. Nagar                 1736
# J.P. Nagar                 1637
# Madiwala                   1563
# V.V.Puram (C.Pet)          1556
# Sadashivanagar             1445
# Kamakshipalya              1431
# Banashankari               1202
# Jalahalli                  1160
# Jnanabharathi              1063
# Peenya                      974
# Devanahalli Airport         940
# Hennuru                     892
# K.G. Halli                  892
# Thalagattapura              870
# K.S. Layout                 828
# Chikkabanavara              785
# Kengeri                     464
# No Police Station           339
# Name: count, dtype: int64
